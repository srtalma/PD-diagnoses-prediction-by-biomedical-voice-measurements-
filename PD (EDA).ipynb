# %% [markdown]
# # 3-EDA

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn.metrics

# %%
#import our first dataset
df1 = pd.read_csv('df1.csv')
df1.head()
# Out:
#    age  sex  test_time  motor_UPDRS  total_UPDRS   Jitter  Jitter_Abc  \
# 0   72    0     5.6431       28.199       34.398  0.00662    0.000034
# 1   72    0    12.6660       28.447       34.894  0.00300    0.000017
# 2   72    0    19.6810       28.695       35.389  0.00481    0.000025
# 3   72    0    25.6470       28.905       35.810  0.00528    0.000027
# 4   72    0    33.6420       29.187       36.375  0.00335    0.000020
#
#    Jitter_RAP  Jitter_PPQ5  Jitter_DDP  ...  Shimmer_dB  Shimmer_APQ3  \
# 0     0.00401      0.00317     0.01204  ...       0.230       0.01438
# 1     0.00132      0.00150     0.00395  ...       0.179       0.00994
# 2     0.00205      0.00208     0.00616  ...       0.181       0.00734
# 3     0.00191      0.00264     0.00573  ...       0.327       0.01106
# 4     0.00093      0.00130     0.00278  ...       0.176       0.00679
#
#    Shimmer_APQ5  Shimmer_APQ11  Shimmer_DDA       NHR     HNR     RPDE  \
# ...

# %%
df1.describe()
# Out:
#                age          sex    test_time  motor_UPDRS  total_UPDRS  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000
# mean     64.804936     0.317787    92.863722    21.296229    29.018942
# std       8.821524     0.465656    53.445602     8.129282    10.700283
# min      36.000000     0.000000    -4.262500     5.037700     7.000000
# 25%      58.000000     0.000000    46.847500    15.000000    21.371000
# 50%      65.000000     0.000000    91.523000    20.871000    27.576000
# 75%      72.000000     1.000000   138.445000    27.596500    36.399000
# max      85.000000     1.000000   215.490000    39.511000    54.992000
#
#             Jitter   Jitter_Abc   Jitter_RAP  Jitter_PPQ5   Jitter_DDP  ...  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000  ...
# mean      0.006154     0.000044     0.002987     0.003277     0.008962  ...
# std       0.005624     0.000036     0.003124     0.003732     0.009371  ...
# ...

# %%
df1.sex.value_counts()
# Out:
# 0    4008
# 1    1867
# Name: sex, dtype: int64

# %%
plt.figure(figsize=[10,5])
gender = np.array([4008, 1867])
sex = ["Male", "Female"]

plt.pie(gender, labels = sex,  colors=['lightblue','pink'],shadow=True);

plt.savefig('gender.jpg', dpi=300)

# %% [markdown]
# The symbol of World Parkinson's Disease is a red tulip
#
# I plot my data with the color of this flower

# %%
plt.figure(figsize=[14,4])
sns.histplot(df1['test_time'], kde=True,bins=10, stat='frequency', color='r',);
sns.set_style("white")
plt.savefig('test_time.jpg', dpi=300)

# %%
plt.figure(figsize=[14,4])
sns.histplot(df1['total_UPDRS'], kde=False,bins=52, stat='frequency', color='r',);
sns.set_style("white")
plt.savefig('total_UPDRS.jpg', dpi=300)

# %%
plt.figure(figsize=[14,4])
sns.histplot(df1['motor_UPDRS'], kde=False,bins=52, stat='frequency', color='r');
sns.set_style("white")
plt.savefig('motor_UPDRS.jpg', dpi=300)

# %%
#drop some columns as long as we don't need them
df1.drop(labels=['age','sex'], axis=1,inplace=True)
df1.head(2)
# Out:
#    test_time  motor_UPDRS  total_UPDRS   Jitter  Jitter_Abc  Jitter_RAP  \
# 0     5.6431       28.199       34.398  0.00662    0.000034     0.00401
# 1    12.6660       28.447       34.894  0.00300    0.000017     0.00132
#
#    Jitter_PPQ5  Jitter_DDP  Shimmer  Shimmer_dB  Shimmer_APQ3  Shimmer_APQ5  \
# 0      0.00317     0.01204  0.02565       0.230       0.01438       0.01309
# 1      0.00150     0.00395  0.02024       0.179       0.00994       0.01072
#
#    Shimmer_APQ11  Shimmer_DDA       NHR     HNR     RPDE      DFA      PPE
# 0        0.01662      0.04314  0.014290  21.640  0.41888  0.54842  0.16006
# 1        0.01689      0.02982  0.011112  27.183  0.43493  0.56477  0.10810

# %%
df1['Jitter'].plot.kde(color='r');
plt.savefig('Jitter.jpg', dpi=300)

# %%
df1['Jitter_Abc'].plot.kde(color='r');
plt.savefig('Jitter_Abc.jpg', dpi=300)

# %%
df1['total_UPDRS'].plot.kde(color='r');
plt.savefig('total_UPDRS.jpg', dpi=300)

# %% [markdown]
# Speech appears explicitly in sections 5 and 18 of the UPDRS metric.
#
# motor-UPDRS(p < 0.001, Spearman ρ = 0.44)
#
# total- UPDRS(p < 0.001, ρ = 0.51)

# %%
df1.corr(method='spearman')
# Out:
#                test_time  motor_UPDRS  total_UPDRS    Jitter  Jitter_Abc  \
# test_time       1.000000     0.058746     0.061699 -0.007409   -0.008382
# motor_UPDRS     0.058746     1.000000     0.957818  0.127905    0.072467
# total_UPDRS     0.061699     0.957818     1.000000  0.129237    0.104178
# Jitter         -0.007409     0.127905     0.129237  1.000000    0.902065
# Jitter_Abc     -0.008382     0.072467     0.104178  0.902065    1.000000
# Jitter_RAP     -0.016707     0.106679     0.109214  0.956166    0.821846
# Jitter_PPQ5    -0.004507     0.120092     0.118347  0.959100    0.886542
# Jitter_DDP     -0.016677     0.106731     0.109251  0.956176    0.821845
# Shimmer        -0.025699     0.136186     0.137550  0.652681    0.624907
# Shimmer_dB     -0.020741     0.140127     0.139915  0.673114    0.634172
# Shimmer_APQ3   -0.018772     0.113784     0.119909  0.616051    0.579700
# Shimmer_APQ5   -0.022814     0.121267     0.124940  0.622316    0.606298
# ...

# %%
plt.figure(figsize=[14,9])
sns.heatmap(df1.corr(method='spearman'),cmap='Blues');
plt.savefig('spearman_corr.jpg', dpi=300)

# %%
#import our second dataset
df2 = pd.read_csv('df1.csv')
df2.head(2)
# Out:
#    age  sex  test_time  motor_UPDRS  total_UPDRS   Jitter  Jitter_Abc  \
# 0   72    0     5.6431       28.199       34.398  0.00662    0.000034
# 1   72    0    12.6660       28.447       34.894  0.00300    0.000017
#
#    Jitter_RAP  Jitter_PPQ5  Jitter_DDP  ...  Shimmer_dB  Shimmer_APQ3  \
# 0     0.00401      0.00317     0.01204  ...       0.230       0.01438
# 1     0.00132      0.00150     0.00395  ...       0.179       0.00994
#
#    Shimmer_APQ5  Shimmer_APQ11  Shimmer_DDA       NHR     HNR     RPDE  \
# 0       0.01309        0.01662      0.04314  0.014290  21.640  0.41888
# 1       0.01072        0.01689      0.02982  0.011112  27.183  0.43493
#
#        DFA      PPE
# 0  0.54842  0.16006
# 1  0.56477  0.10810
#
# [2 rows x 21 columns]

# %%
#drop some columns as long as we don't need them
df2.drop(labels=['age','sex'], axis=1,inplace=True)
df2.head(2)
# Out:
#    test_time  motor_UPDRS  total_UPDRS   Jitter  Jitter_Abc  Jitter_RAP  \
# 0     5.6431       28.199       34.398  0.00662    0.000034     0.00401
# 1    12.6660       28.447       34.894  0.00300    0.000017     0.00132
#
#    Jitter_PPQ5  Jitter_DDP  Shimmer  Shimmer_dB  Shimmer_APQ3  Shimmer_APQ5  \
# 0      0.00317     0.01204  0.02565       0.230       0.01438       0.01309
# 1      0.00150     0.00395  0.02024       0.179       0.00994       0.01072
#
#    Shimmer_APQ11  Shimmer_DDA       NHR     HNR     RPDE      DFA      PPE
# 0        0.01662      0.04314  0.014290  21.640  0.41888  0.54842  0.16006
# 1        0.01689      0.02982  0.011112  27.183  0.43493  0.56477  0.10810

# %%
# Save output as CSV
df1.to_csv('df1_modeling.csv', index=False)
df2.to_csv('df2_modeling.csv', index=False)

# %% [markdown]
# # Here we go!! our data is ready for Validation and modeling.
